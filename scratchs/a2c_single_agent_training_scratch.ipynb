# %%
import os
import sys
sys.path.append("../source/")

from run import StockTrader

# %% [markdown]
# ### 1. Set up training environment for single agent

# %%
simulator = StockTrader(
    mode="train",
    config_file_name="train_config.json"
)

# %% [markdown]
# ### 2. Get Start training

# %%
simulator.train()
# Out:
# [1] Declare data processor
# [2] Load dataset and apply preprocessing
# Append technical indicators
# Append turbulence index
# Append user-defined-feature
# [3] Set environment
# [4] Ready for training
# [5] Run!
# (13,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-cde2eb37394a> in <module>
# ----> 1 simulator.train()
#
# ~/Desktop/code/project/rl-stock-trading/source/run.py in train(self)
#      89         # Train agent
#      90         print("[5] Run!")
# ---> 91         simulator.train()
#      92
#      93     def trade(self):
#
# ~/Desktop/code/project/rl-stock-trading/source/strategy/a2c.py in train(self)
#     161             while not b_terminal:
#     162                 # Actor an action by following the current policy
# --> 163                 action = self.get_next_action(curr_state)
#     164
# ...
